# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahSouzaPontes/histograma_distribuicao/blob/main/histogramas_e_distribuicoes1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df= pd.read_csv('/content/base_prob.csv')
print(df)
# Out:
#         age  SeriousDlqin2yrs  MonthlyIncome
# 0        45                 1         9120.0
# 1        40                 0         2600.0
# 2        38                 0         3042.0
# 3        30                 0         3300.0
# 4        74                 0         3500.0
# ...     ...               ...            ...
# 119995   59                 0        10316.0
# 119996   22                 0          820.0
# 119997   50                 0         3400.0
# 119998   74                 0         2100.0
# 119999   44                 0         5584.0
#
# [120000 rows x 3 columns]

# %%
plt.hist(df.age)
# Out:
# (array([1.0000e+00, 0.0000e+00, 9.0490e+03, 2.3656e+04, 2.9826e+04,
#         2.7546e+04, 2.0138e+04, 7.6550e+03, 2.0130e+03, 1.1600e+02]),
#  array([  0. ,  10.3,  20.6,  30.9,  41.2,  51.5,  61.8,  72.1,  82.4,
#          92.7, 103. ]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1),rwidth=.8);

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1),rwidth=.8);

plt.xlabel('Idade')
plt.ylabel('Contagem de pessoas')
# Out:
# Text(0, 0.5, 'Contagem de pessoas')

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1),rwidth=.8);

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Contagem de pessoas', fontsize=16)
# Out:
# Text(0, 0.5, 'Contagem de pessoas')

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1),rwidth=.8);

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Contagem de pessoas', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([   0.,  500., 1000., 1500., 2000., 2500., 3000., 3500.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1),rwidth=.8);

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Contagem de pessoas', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1),rwidth=.8,density=True);

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Probabilidade/Idade', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1),rwidth=.8,density=True);
plt.axvline(29,color='k')

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Probabilidade/Idade', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1),rwidth=.8,density=True);
plt.axvline(29,color='k')
plt.axhline(0.0125,color='k')

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Probabilidade/Idade', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

# %%
plt.figure(figsize=(15,5))
plt.hist(df.age, bins=np.arange(0,101,1),rwidth=.8,density=True);
plt.axvline(29,color='k')
plt.axhline(0.0125,color='k')

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Probabilidade/Idade', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks([0,0.005,0.010,0.0125,0.015,0.020,0.025],fontsize=16)
plt.grid()

# %% [markdown]
# # Distribuição de probabilidade conjunta

# %%
plt.figure(figsize=(15,5))
#plt.hist(df.age, bins=np.arange(0,101,1),rwidth=.8,density=True);
plt.hist2d(df.age, df.MonthlyIncome, bins=30, density=True)

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Probabilidade/Idade', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

# %%
plt.figure(figsize=(15,5))
#plt.hist(df.age, bins=np.arange(0,101,1),rwidth=.8,density=True);
plt.hist2d(df.age, df.MonthlyIncome, bins=30, density=True)

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Probabilidade/Idade', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
plt.figure(figsize=(15,5))
#plt.hist(df.age, bins=np.arange(0,101,1),rwidth=.8,density=True);
plt.hist2d(df.age, df.MonthlyIncome, bins=30, density=True)
plt.colorbar()

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Probabilidade/Idade', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df.MonthlyIncome,bins=30,density=True)

plt.subplot(1,2,2)
plt.hist2d(df.age, df.MonthlyIncome, bins=30, density=True)
plt.colorbar()

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Probabilidade/Idade', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df.MonthlyIncome,bins=30,density=True,orientation='horizontal',rwidth=.8)

plt.xticks(fontsize=16,rotation=45)
plt.yticks(fontsize=16)

plt.subplot(1,2,2)
plt.hist2d(df.age, df.MonthlyIncome, bins=30, density=True)
plt.colorbar()

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Probabilidade/Idade', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
plt.figure(figsize=(15,5))

plt.subplot(2,2,1)
plt.hist(df.MonthlyIncome,bins=30,density=True,orientation='horizontal',rwidth=.8)

plt.xticks(fontsize=16,rotation=45)
plt.yticks(fontsize=16)

plt.subplot(2,2,2)
plt.hist2d(df.age, df.MonthlyIncome, bins=30, density=True)
plt.colorbar()

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Probabilidade/Idade', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)


plt.subplot(2,2,4)
plt.hist(df.age,bins=30,density=True,orientation='vertical',rwidth=.8)

plt.xticks(fontsize=16,rotation=45)
plt.yticks(fontsize=16)
# Out:
# (array([0.  , 0.01, 0.02, 0.03, 0.04]),
#  <a list of 5 Text major ticklabel objects>)

# %%
plt.figure(figsize=(15,2*5))

plt.subplot(2,2,1)
plt.hist(df.MonthlyIncome,bins=30,density=True,orientation='horizontal',rwidth=.8)

plt.xticks(fontsize=16,rotation=45)
plt.yticks(fontsize=16)

plt.subplot(2,2,2)
plt.hist2d(df.age, df.MonthlyIncome, bins=30, density=True)
plt.colorbar()

plt.xlabel('Idade', fontsize=16)
plt.ylabel('Probabilidade/Idade', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)


plt.subplot(2,2,4)
plt.hist(df.age,bins=30,density=True,orientation='vertical',rwidth=.8)

plt.xticks(fontsize=16,rotation=45)
plt.yticks(fontsize=16)
# Out:
# (array([0.   , 0.005, 0.01 , 0.015, 0.02 , 0.025, 0.03 , 0.035]),
#  <a list of 8 Text major ticklabel objects>)
